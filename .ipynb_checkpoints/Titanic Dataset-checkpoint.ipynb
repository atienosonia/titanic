# %%
#VARIABLE DEFINITION
#survival = (Survived 0=No;1=Yes)
#class = Passenger Class(1=1st,2=2nd,3=3rd)
#name-name
#sex-sex
#age - age
#sibsp-Numbe of siblings/Spouses aboard
#parch - number of children/parents aboard
#ticket - Ticket Number
#fare- Passenger Fare
#cabin - cabin
#embarked -port of embarkation(C=Cherbough, Q=Queenstown, S=SouthHampton )
#boat = lifeboat (if survived )
#dead = body number(if did not surive and body was recovered)

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv(r"D:\train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#familiarizing with or data

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.set_index("PassengerId", inplace=True)
#changing our index from 0-891 to the passengers ID column

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df["Cabin"].value_counts()
# Out:
# G6             4
# C23 C25 C27    4
# B96 B98        4
# E101           3
# F2             3
#               ..
# C148           1
# B94            1
# B102           1
# C47            1
# F38            1
# Name: Cabin, Length: 147, dtype: int64

# %%
df.loc[4]
# Out:
# Survived                                               1
# Pclass                                                 1
# Name        Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                               female
# Age                                                 35.0
# SibSp                                                  1
# Parch                                                  0
# Ticket                                            113803
# Fare                                                53.1
# Cabin                                               C123
# Embarked                                               S
# Name: 4, dtype: object

# %%
df.drop(axis="columns", columns=["Fare", "Cabin"], inplace=True)
#dropping the cabin and the fare column. We already have the passenger class i.e the first class therefore we do not need
#to know whaere the passenger resided in during the journey.

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.shape
# Out:
# (891, 9)

# %%
df.drop_duplicates()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.shape
# Out:
# (891, 9)

# %%
#our data does not have any duplicates

# %%
df.isna()
#checking for any missing values in our dataframe
# Out:
#              Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# PassengerId
# 1               False   False  False  False  False  False  False   False
# 2               False   False  False  False  False  False  False   False
# 3               False   False  False  False  False  False  False   False
# 4               False   False  False  False  False  False  False   False
# 5               False   False  False  False  False  False  False   False
# ...               ...     ...    ...    ...    ...    ...    ...     ...
# 887             False   False  False  False  False  False  False   False
# 888             False   False  False  False  False  False  False   False
# 889             False   False  False  False   True  False  False   False
# 890             False   False  False  False  False  False  False   False
# 891             False   False  False  False  False  False  False   False
#
#              Embarked
# PassengerId
# 1               False
# ...

# %%
df.isna().value_counts()
#tallying up responses to either False or True
# Out:
# Survived  Pclass  Name   Sex    Age    SibSp  Parch  Ticket  Embarked
# False     False   False  False  False  False  False  False   False       712
#                                 True   False  False  False   False       177
#                                 False  False  False  False   True          2
# dtype: int64

# %%
df.fillna("MISSING")
#filling in all missing data wiht the word "MISSING " instead of NaN(Not a Number)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
df_new = df.dropna(axis="index", how="all", subset=["Name","Pclass"])

# %%
df_new
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df_new.shape
# Out:
# (891, 9)

# %%
df.shape
# Out:
# (891, 9)

# %%
#dataset insights 
#no.of people who survved and were female 
#no.of people who died and were female
#no.of males who died 
#no. of males who survived #age bracket of people who survived the sinking
#siblings and parents who survived 
# patients and children aboard who survived

# %%
df_new
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df_new.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Embarked'],
#       dtype='object')

# %%
df_new.groupby("Sex")
#we want to group our data based on the sex of the people who aboarded the train.

# %%
sex_grp = df_new.groupby("Sex")

# %%
sex_grp["Survived"].value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
type(sex_grp["Survived"].value_counts())
# Out:
# pandas.core.series.Series

# %%
filt = df_new["Sex"] == "female"
df_new[filt]["Survived"].value_counts()
#tally up of the number of females  who survived and died
# Out:
# 1    233
# 0     81
# Name: Survived, dtype: int64

# %%
type(df_new[filt]["Survived"].value_counts())
# Out:
# pandas.core.series.Series

# %%
filt = df_new["Sex"] == "male"
df_new.loc[filt]["Survived"].value_counts()
#tally up of the number of males who survivded and died
# Out:
# 0    468
# 1    109
# Name: Survived, dtype: int64

# %%
type(df_new.loc[filt]["Survived"].value_counts())
# Out:
# pandas.core.series.Series

# %%
df_array = np.array(df_new.loc[filt]["Survived"].value_counts())

# %%
df_array
# Out:
# array([468, 109], dtype=int64)

# %%
df_int = df_array.astype(int)

# %%
df_int
# Out:
# array([468, 109])

# %%
df_list = df_int.tolist()

# %%
df_list
# Out:
# [468, 109]

# %%
type(df_list[0])
# Out:
# int

# %%
import matplotlib.pyplot as plt

slices = df_list
labels = ["Died", "Survived"]
explode = [0, 0.05]

#customization
plt.title("PieChart Showing Portion Of Males Who Survived and Those Who Died")
plt.tight_layout()

plt.pie(slices,labels=labels, shadow=True,explode=explode, wedgeprops={"edgecolor":"black"})
plt.show()

# %%
filt = df_new["Sex"] == "female"
df_female_survived = df.loc[filt]["Survived"].value_counts()

# %%
df_female_survived
# Out:
# 1    233
# 0     81
# Name: Survived, dtype: int64

# %%
type(df_female_survived)
# Out:
# pandas.core.series.Series

# %%
df_female_survived_array = np.array(df_female_survived)

# %%
type(df_female_survived_array)
# Out:
# numpy.ndarray

# %%
df_female_survived_int = df_female_survived_array.astype(int)

# %%
type(df_female_survived_int)
# Out:
# numpy.ndarray

# %%
df_female_survived_list = df_female_survived_int.tolist()

# %%
type(df_female_survived_list)
#remember to call the right variable
# Out:
# list

# %%
slices = df_female_survived_list
labels = ["Survived","Died"]
explode = [0, 0.05]
colors = ["#e5ae37", "#6d904f"]

#customizations
plt.title("PieChart Showing Female Portion Who Survived And Died During The Sinking")
plt.tight_layout()

plt.pie(slices,labels=labels,explode=explode, colors=colors, shadow=True,wedgeprops={"edgecolor":"black"})
plt.show()

# %%
#the number of female proportion who survived the titanic are greater as opposed to the number of males who survived the titanic 
#more males died as opposed to females in the titanic

# %%
df_new.groupby("Pclass")

# %%
df_new_pclass =df_new.groupby("Pclass")

# %%
df_new_pclass["Survived"].value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
type(df_new_pclass["Survived"].value_counts())
# Out:
# pandas.core.series.Series

# %%
df_new_pclass_array = np.array(df_new_pclass["Survived"].value_counts())

# %%
type(df_new_pclass_array )
# Out:
# numpy.ndarray

# %%
df_new_pclass_list = df_new_pclass_array.tolist()

# %%
type(df_new_pclass_list)
# Out:
# list

# %%
df_new_pclass_list
# Out:
# [136, 80, 97, 87, 372, 119]
